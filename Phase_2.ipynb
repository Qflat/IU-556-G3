# %%
# Import data from zip file
from pandas import read_csv
application_train = read_csv('application_train.csv', chunksize=100000)
application_test = read_csv('application_test.csv', chunksize=100000)
bureau = read_csv('bureau.csv', chunksize=100000)
bureau_balance = read_csv('bureau_balance.csv', chunksize=100000)
credit_card_balance = read_csv('credit_card_balance.csv', chunksize=100000)
installments_payments = read_csv('installments_payments.csv', chunksize=100000)
POS_CASH_balance = read_csv('POS_CASH_balance.csv', chunksize=100000)
previous_application = read_csv('previous_application.csv', chunksize=100000)
sample_submission = read_csv('sample_submission.csv', chunksize=100000)
submission = read_csv('submission.csv', chunksize=100000)
HomeCredit_columns_description = read_csv('HomeCredit_columns_description.csv',encoding='latin1', chunksize=100000)
